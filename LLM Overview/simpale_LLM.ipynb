# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "gpt2"
)

text = "I love artificial intelligence"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['I', 'Ġlove', 'Ġartificial', 'Ġintelligence']

# %%
token_ids = tokenizer.encode(text)

print(token_ids)
# Out:
# [40, 1842, 11666, 4430]

# %%
decoded = tokenizer.decode(token_ids)

print(decoded)
# Out:
# I love artificial intelligence

# %% [markdown]
# Simple Text Generation

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

result = generator(
    "Artificial intelligence is",
    max_new_tokens=30
)

print(result[0]["generated_text"])
# print(result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial intelligence is a unique technology that allows for the creation of unique, personalized experiences that will benefit everyone.
#
# Here are some examples of how artificial intelligence can help
# [{'generated_text': 'Artificial intelligence is a unique technology that allows for the creation of unique, personalized experiences that will benefit everyone.\n\nHere are some examples of how artificial intelligence can help'}]
