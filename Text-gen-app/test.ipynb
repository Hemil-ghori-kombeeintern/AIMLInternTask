# %%
import os

from dotenv import load_dotenv
from google import genai

load_dotenv()
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

prompt = (
    "What is artificial intelligence? Explain it in a complete, detailed paragraph "
    "of approximately 150 to 250 words. Do not stop after the introduction."
)
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt,
    config={
        "max_output_tokens": 300,
        "temperature": 0.7,
        "thinking_config": {
            "thinking_level": "minimal",
        },
    },
)

print(response.text)
if response.candidates:
    print("\nFinish reason:", response.candidates[0].finish_reason)
# Out:
# Artificial intelligence (AI) is a multidisciplinary field of computer science dedicated to creating systems capable of performing tasks that traditionally require human intelligence. These tasks encompass a wide range of cognitive functions, including natural language understanding, visual perception, pattern recognition, decision-making, and problem-solving. At its core, AI relies on advanced algorithms, vast datasets, and computational power to process information, learn from experience, and adapt to new inputs without being explicitly programmed for every specific scenario. Modern AI is largely driven by machine learning and deep learning, subfields that utilize complex neural networks modeled after the human brain to detect subtle correlations in data and make accurate predictions. Currently, AI exists primarily as "narrow" or "weak" AI, which excels at highly specialized applications such as driving autonomous vehicles, powering virtual assistants, diagnosing medical conditions, and generating human-like text. As research progresses, the ultimate, albeit theoretical, goal for many scientists remains Artificial General Intelligence (AGI)—systems that possess broad, human-level adaptability across any intellectual domain. Ultimately, artificial intelligence is transforming society by automating labor, augmenting human capabilities, and fundamentally reshaping how we interact with technology and analyze the world around us.
#
# Finish reason: FinishReason.STOP
